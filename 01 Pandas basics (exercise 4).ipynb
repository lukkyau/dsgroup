# %%
# %matplotlib inline
import pandas as pd

# %%
# Print all outputs in jupyter notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
titles = pd.read_csv('pycon-pandas-tutorial/data/titles.csv')
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2   The Spider and the Fly  1949
# 3                  Country  2000
# 4          The Golden Note  2017

# %%
cast = pd.read_csv('pycon-pandas-tutorial/data/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### Define a year as a "Superman year" whose films feature more Superman characters than Batman. How many years in film history have been Superman years?

# %%
c=cast
c.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c=c[(c.character=="Superman")|(c.character=="Batman")]
d=c.groupby(['year','character']).size().sort_index()
d.unstack('character').fillna(0)
d.Batman - d.Superman
# Out:
# character  Batman  Superman
# year
# 1938          1.0       0.0
# 1940          1.0       0.0
# 1943          1.0       0.0
# 1948          0.0       1.0
# 1949          2.0       0.0
# 1950          0.0       1.0
# 1951          0.0       2.0
# 1953          2.0       0.0
# 1954          0.0       5.0
# 1955          0.0       1.0
# 1957          2.0       0.0
# 1965          1.0       0.0
# 1966          1.0       0.0
# 1967          1.0       0.0
# 1973          1.0       2.0
# 1978          0.0       2.0
# 1980          0.0       2.0
# 1981          1.0       1.0
# 1983          0.0       2.0
# 1985          2.0       2.0
# 1987          0.0       1.0
# 1988          1.0       0.0
# 1989          1.0       0.0
# 1991          1.0       1.0
# 1992          1.0       1.0
# 1993          2.0       0.0
# 1994          1.0       1.0
# 1995          1.0       1.0
# 1997          1.0       1.0
# 1998          1.0       0.0
# 1999          1.0       0.0
# 2002          1.0       1.0
# 2003          1.0       1.0
# 2004          1.0       0.0
# 2005          1.0       0.0
# 2006          0.0       1.0
# 2008          3.0       2.0
# 2009          3.0       1.0
# 2010          3.0       1.0
# 2011          4.0       2.0
# 2012          2.0       1.0
# 2013          5.0       1.0
# 2014          5.0       1.0
# 2015          4.0       1.0
# 2016         12.0       4.0
# 2017          9.0       5.0
# 2018          4.0       2.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-fab2010285ec> in <module>
#       2 d=c.groupby(['year','character']).size().sort_index()
#       3 d.unstack('character').fillna(0)
# ----> 4 d.Batman - d.Superman
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'Batman'

# %% [markdown]
# ### How many years have been "Batman years", with more Batman characters than Superman characters?

# %% [markdown]
# ### Plot the number of actor roles each year and the number of actress roles each year over the history of film.

# %% [markdown]
# ### Plot the number of actor roles each year and the number of actress roles each year, but this time as a kind='area' plot.

# %% [markdown]
# ### Plot the difference between the number of actor roles each year and the number of actress roles each year over the history of film.

# %% [markdown]
# ### Plot the fraction of roles that have been 'actor' roles each year in the history of film.

# %% [markdown]
# ### Plot the fraction of supporting (n=2) roles that have been 'actor' roles each year in the history of film.

# %% [markdown]
# ### Build a plot with a line for each rank n=1 through n=3, where the line shows what fraction of that rank's roles were 'actor' roles for each year in the history of film.
