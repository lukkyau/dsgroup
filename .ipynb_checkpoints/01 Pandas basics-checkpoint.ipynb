# %% [markdown]
# # Pandas
# Introduction to pandas using Brandon's tutorial
#
# For notebook shortcuts - just hit ```h```
#
# https://github.com/brandon-rhodes/pycon-pandas-tutorial
#
# ## Exercise 1

# %%
# Print all outputs in jupyter notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Allows matplotlib to draw graphics in notebook, rather than separate window
# %matplotlib inline 
import pandas as pd

# %%
# Note that the DataFrame.from_csv has been deprecated - replaced by pd.read_csv
titles=pd.read_csv('pycon-pandas-tutorial/data/titles.csv', index_col=None, encoding='utf-8')
titles.head()

cast=pd.read_csv('pycon-pandas-tutorial/data/cast.csv', index_col=None, encoding='utf-8')
cast.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2   The Spider and the Fly  1949
# 3                  Country  2000
# 4          The Golden Note  2017
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
titles
# Out:
#                           title  year
# 0                The Rising Son  1990
# 1       The Thousand Plane Raid  1969
# 2        The Spider and the Fly  1949
# 3                       Country  2000
# 4               The Golden Note  2017
# ...                         ...   ...
# 244909                    E yue  2005
# 244910             Lakota Girls  2015
# 244911           Kroniki domowe  1997
# 244912     Awakening the Zodiac  2017
# 244913           American Satan  2017
#
# [244914 rows x 2 columns]

# %%
len(titles)
# Out:
# 244914

# %%
# Ask for fewer rows to just remind yourself what the data was
# This creates a new dataframe - so if you've sorted it, you can use it to get the subset you want 
# i.e. it's a proper data slicing/reduction step
h=titles.head(5)
t=titles.tail(5)
h
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2   The Spider and the Fly  1949
# 3                  Country  2000
# 4          The Golden Note  2017

# %%
# Each column is called a SERIES (when they're in the dataframe they're called columns)
# Can use square brackets to look up series, or a simple attribute (lower case, no special characters)
h['year']
h.year
# Out:
# 0    1990
# 1    1969
# 2    1949
# 3    2000
# 4    2017
# Name: year, dtype: int64
# 0    1990
# 1    1969
# 2    1949
# 3    2000
# 4    2017
# Name: year, dtype: int64

# %%
# You can also do operations on series (e.g. mod10)
h['year'] // 10 * 10
h.year >1985
# Out:
# 0    1990
# 1    1960
# 2    1940
# 3    2000
# 4    2010
# Name: year, dtype: int64
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: year, dtype: bool

# %%
# You can use boolean series above (array of true/falses) to filter out from another data series
h[h.year>1985]

# For multiple conditions, need to use either & (not AND) or | (not OR)
# Note that you need to put both conditions in brackets, otherwise python will try to do 
# "1980 & h.year" FIRST then the booleans around it (due to operator precedence - but not what we want)
h[(h.year<1980) & (h.year >=1990)]
h[(h.year<1980) | (h.year >=1990)]
# Out:
#              title  year
# 0   The Rising Son  1990
# 3          Country  2000
# 4  The Golden Note  2017
# Empty DataFrame
# Columns: [title, year]
# Index: []
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2   The Spider and the Fly  1949
# 3                  Country  2000
# 4          The Golden Note  2017

# %%
t=titles
t[t.title=="Macbeth"].sort_values('year')
# This creates a dataframe, then we use the SORT_VALUES 
# Can also add on TAIL() and HEAD() to this data frame as well
# Out:
#           title  year
# 4407    Macbeth  1913
# 71411   Macbeth  1916
# 149536  Macbeth  1948
# 215678  Macbeth  1987
# 17973   Macbeth  1997
# 166888  Macbeth  1998
# 91697   Macbeth  2003
# 140102  Macbeth  2004
# 58888   Macbeth  2006
# 159718  Macbeth  2009
# 150816  Macbeth  2012
# 12245   Macbeth  2013
# 110636  Macbeth  2014
# 133221  Macbeth  2015
# 195292  Macbeth  2017
# 47807   Macbeth  2018

# %% [markdown]
# ![image.png](attachment:image.png)
# Note that these include deprecated commands (e.g. previously needed to ORDER a series, but SORT a dataframe - but this has now been made consistent using SORT)
#
# https://youtu.be/5JnMutdy6Fw?t=2309

# %%
# Previously needed to ORDER a SERIES but SORT a dataframe - now just need to sort
titles['year'].sort_values()
# Out:
# 187327    1894
# 226857    1898
# 131240    1899
# 193369    1900
# 100010    1900
#           ...
# 182148    2024
# 70854     2024
# 135523    2025
# 154901    2026
# 9533      2115
# Name: year, Length: 244914, dtype: int64

# %%
h=cast.head()
not_null=h[h.n.notnull()] 
is_null=h[h.n.isnull()]
#Computing this doesn't show anything, need to save to name (or just htrows away)
h
not_null
is_null
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN
#                  title  year      name   type        character     n
# 0       Closet Monster  2015  Buffy #1  actor          Buffy 4  31.0
# 1      Suuri illusioni  1985    Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017   $hutter  actor  Bobby Riggs Fan  10.0
#                   title  year     name   type                character   n
# 3  Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan NaN
# 4            Steve Jobs  2015  $hutter  actor  1988 Opera House Patron NaN

# %% [markdown]
# Finished exercise 1 - see separate jupyter notebook
#
# https://youtu.be/5JnMutdy6Fw?t=2656

# %% [markdown]
# # Exercise 2

# %% [markdown]
# - With series, can't use all the standard python STRING methods because of collisions (e.g. can't just do ```series.startswith('hello')```) But can just attach on ```.str``` like - ```series.str.startswith('hello')```. This contains all the string methods.

# %%
t=titles
t=t[t.title.str.startswith('Hamlet')]
t
# Out:
#                                 title  year
# 2371             Hamlet Demonstration  2011
# 6320                           Hamlet  1948
# 9061                      Hamlet (II)  2005
# 9367                      Hamlet (II)  2015
# 15984                  Hamlet Unbound  2012
# 18345       Hamlet, Prince of Denmark  1997
# 28356                     Hamlet (II)  2007
# 28692                  Hamlet/Horatio  2017
# 31546                     Hamlet (II)  2017
# 39215                        Hamlet_X  2003
# 41403        Hamlet, Son of a Kingpin  2015
# 47163                    Hamlet (III)  2007
# 49308                          Hamlet  1910
# 52004                          Hamlet  2017
# 77194                          Hamlet  1954
# 77870                  Hamlet's Ghost  2015
# 79072                          Hamlet  2015
# 83215   Hamlet: The Fall of a Sparrow  2018
# 83372                        Hamlet X  2004
# 97017                          Hamlet  1976
# ...

# %% [markdown]
# - Can use ```titles.year.value_counts()``` that gives you a frequency distribution of the series. Can also use the ```.plot()``` method to create a graph.

# %%
t=titles
t=titles.year.value_counts() 
t
titles.year.value_counts().plot() 
# But this is sorted by frequency, so not reasonable
# We know how to sort data (sort_values), but we want to sort by the INDEX
titles.year.value_counts().sort_index()
titles.year.value_counts().sort_index().plot()
# Out:
# 2017    11474
# 2016     9440
# 2015     8702
# 2014     8264
# 2018     8041
#         ...
# 2026        1
# 1894        1
# 1898        1
# 2025        1
# 2115        1
# Name: year, Length: 128, dtype: int64
# 1894    1
# 1898    1
# 1899    1
# 1900    5
# 1903    1
#        ..
# 2023    5
# 2024    6
# 2025    1
# 2026    1
# 2115    1
# Name: year, Length: 128, dtype: int64

# %%
c=cast
c=c[c.character=="Kermit the Frog"]
c.head()
# .plot automatically uses the index, but you can change it to year for x-axis
c.plot(x='year',y='n',kind='scatter')
# Out:
#                                  title  year        name   type  \
# 982460  An American Werewolf in London  1981  Jim Henson  actor
# 982461                Follow That Bird  1985  Jim Henson  actor
# 982466          The Great Muppet Caper  1981  Jim Henson  actor
# 982474                The Muppet Movie  1979  Jim Henson  actor
# 982481      The Muppets Take Manhattan  1984  Jim Henson  actor
#
#               character     n
# 982460  Kermit the Frog  18.0
# 982461  Kermit the Frog   2.0
# 982466  Kermit the Frog   1.0
# 982474  Kermit the Frog   1.0
# 982481  Kermit the Frog   1.0

# %%
# To simplify tables, then you can use DOUBLE square brackets [[]] 
# after your dataframe to what you want
c.head()[['year','n']]
# Out:
#         year     n
# 982460  1981  18.0
# 982461  1985   2.0
# 982466  1981   1.0
# 982474  1979   1.0
# 982481  1984   1.0
